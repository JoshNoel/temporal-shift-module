# %%
from gmaps_demo import gmaps_wrapper
gmaps = gmaps_wrapper(api_key="AIzaSyBVn2Cvo1Zx4M0sR3h6ES9fk9X0ZfmTHqs")
gmaps.show()
# Out:
# <html>
# <script type="text/Javascript">
#     // Open new window for map
#     var win = window.open("", "TSM Google Maps Navigator", "toolbar=no, location=no, directories=no, status=no, menubar=no, resizable=yes, width=600, height=600");
#     win.document.body.innerHTML = `
#     <head>
#         <title>Gesture Map</title>
#         <meta name="viewport" content="initial-scale=1.0">
#         <meta charset="utf-8">
#     </head>
#     <body>
#         <div style="height:100%; width:100%;">
#             <div id="map" style="height:100%"></div>
#         </div>
#     </body>
# `
# ;
#     // Setup map
#     var map = null;
#     var panorama = null;
#     var overlay = null;
#     var showingStreetViewOverlay = false;
#     var showingStreetView = false;
#
#     function initMap() {
#         // Init map
#         map = new google.maps.Map(win.document.getElementById('map'), {
#             center: { lat: 42.3616, lng: -71.0906 },
#             zoom: 17,
# ...

# %%
gmaps.run(target='cuda')
# Out:
# Open camera...
